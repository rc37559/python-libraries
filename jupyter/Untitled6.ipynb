# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("FIFA - 2018.csv")

# %%
df.head()
# Out:
#    Position     Team  Games Played  Win  Draw  Loss  Goals For  Goals Against  \
# 0         1   France             7    6     1     0         14              6
# 1         2  Croatia             7    4     2     1         14              9
# 2         3  Belgium             7    6     0     1         16              6
# 3         4  England             7    3     1     3         12              8
# 4         5  Uruguay             5    4     0     1          7              3
#
#   Goal Difference  Points
# 0               8      19
# 1               5      14
# 2              10      18
# 3               4      10
# 4               4      12

# %%
df=df.drop(columns='Team')

# %%
df
# Out:
#     Position  Games Played  Win  Draw  Loss  Goals For  Goals Against  \
# 0          1             7    6     1     0         14              6
# 1          2             7    4     2     1         14              9
# 2          3             7    6     0     1         16              6
# 3          4             7    3     1     3         12              8
# 4          5             5    4     0     1          7              3
# 5          6             5    3     1     1          8              3
# 6          7             5    3     0     2          6              4
# 7          8             5    2     2     1         11              7
# 8          9             4    2     1     1          6              3
# 9         10             4    2     0     2          3              6
# 10        11             4    1     3     0          3              2
# 11        12             4    1     3     0          7              6
# ...

# %%
df=df.drop(columns='Goal Difference')

# %%
df
# Out:
#     Position  Games Played  Win  Draw  Loss  Goals For  Goals Against  Points
# 0          1             7    6     1     0         14              6      19
# 1          2             7    4     2     1         14              9      14
# 2          3             7    6     0     1         16              6      18
# 3          4             7    3     1     3         12              8      10
# 4          5             5    4     0     1          7              3      12
# 5          6             5    3     1     1          8              3      10
# 6          7             5    3     0     2          6              4       9
# 7          8             5    2     2     1         11              7       8
# 8          9             4    2     1     1          6              3       7
# 9         10             4    2     0     2          3              6       6
# 10        11             4    1     3     0          3              2       6
# ...

# %%
sns.heatmap(data=df)
import matplotlib.pyplot as plt
plt.figure(figsize(22,33))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17312/2829270591.py in <module>
#       1 sns.heatmap(data=df)
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.figure(figsize(22,33))
#
# NameError: name 'figsize' is not defined

# %%
df.head()
# Out:
#    Position  Games Played  Win  Draw  Loss  Goals For  Goals Against  Points
# 0         1             7    6     1     0         14              6      19
# 1         2             7    4     2     1         14              9      14
# 2         3             7    6     0     1         16              6      18
# 3         4             7    3     1     3         12              8      10
# 4         5             5    4     0     1          7              3      12

# %%
df['Win'].max()
# Out:
# 6
